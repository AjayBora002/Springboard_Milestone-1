# %% [markdown]
# # Milestone 1: Data Preparation & Initial Analysis
# **Project:** ClimateScope: Visualizing Global Weather Trends
# **Author:** [Your Name]
# **Date:** February 2026
#
# ## Objective
# The goal of this milestone is to prepare the "Global Weather Repository" dataset for analysis. This involves:
# 1.  **Data Acquisition:** Downloading the dataset via Kaggle API.
# 2.  **Inspection:** Understanding data types and distributions.
# 3.  **Cleaning:** Handling missing values, duplicates, and correct formatting.
# 4.  **Aggregation:** Creating a monthly summary for trend analysis.

# %%
import pandas as pd
import numpy as np
import os
from kaggle.api.kaggle_api_extended import KaggleApi

# --- CONFIGURATION ---
# Define the folder name for all data files
DATA_FOLDER = 'data'
DATASET_SLUG = 'nelgiriyewithana/global-weather-repository'

# Define file paths using os.path.join (works on Windows/Mac/Linux)
RAW_FILE = os.path.join(DATA_FOLDER, 'GlobalWeatherRepository.csv')
CLEAN_FILE = os.path.join(DATA_FOLDER, 'cleaned_weather_data.csv')
MONTHLY_FILE = os.path.join(DATA_FOLDER, 'monthly_weather_summary.csv')

# Create the 'data' folder if it doesn't exist
os.makedirs(DATA_FOLDER, exist_ok=True)
print(f"Directory '{DATA_FOLDER}' is ready.")
# Out:
# Directory 'data' is ready.

# %% [markdown]
# Automated Data Download. This uses your kaggle.json key.

# %%
# Initialize Kaggle API
api = KaggleApi()

# Check for kaggle.json key
if not os.path.exists('kaggle.json'):
    # Try default system location
    try:
        api.authenticate()
        print("Authenticated with Kaggle system credentials.")
    except Exception as e:
        print(f"Authentication failed: {e}. Please ensure 'kaggle.json' is in the project root.")
else:
    # Use local key file
    os.environ['KAGGLE_CONFIG_DIR'] = os.getcwd()
    api.authenticate()
    print("Authenticated with local kaggle.json.")

# Download Dataset into the 'data' folder
if not os.path.exists(RAW_FILE):
    print(f"Downloading {DATASET_SLUG} into '{DATA_FOLDER}'...")
    api.dataset_download_files(DATASET_SLUG, path=DATA_FOLDER, unzip=True)
    print("Download complete.")
else:
    print(f"Dataset already exists in '{DATA_FOLDER}'.")
# Out:
# Authenticated with local kaggle.json.
# Downloading nelgiriyewithana/global-weather-repository into 'data'...
# Dataset URL: https://www.kaggle.com/datasets/nelgiriyewithana/global-weather-repository
# Download complete.

# %% [markdown]
# Load the data and inspect the structure

# %%
# Load Data
print(f"Loading data from: {RAW_FILE}")
df = pd.read_csv(RAW_FILE)

# Display Basic Info
print(f"Dataset Shape: {df.shape}")
print("\n--- Data Types ---")
print(df.info())

print("\n--- First 5 Rows ---")
display(df.head())
# Out:
# Loading data from: data\GlobalWeatherRepository.csv
# Dataset Shape: (124136, 41)
#
# --- Data Types ---
# <class 'pandas.DataFrame'>
# RangeIndex: 124136 entries, 0 to 124135
# Data columns (total 41 columns):
#  #   Column                        Non-Null Count   Dtype
# ---  ------                        --------------   -----
#  0   country                       124136 non-null  str
#  1   location_name                 124136 non-null  str
#  2   latitude                      124136 non-null  float64
#  3   longitude                     124136 non-null  float64
#  4   timezone                      124136 non-null  str
#  5   last_updated_epoch            124136 non-null  int64
#  6   last_updated                  124136 non-null  str
#  7   temperature_celsius           124136 non-null  float64
#  8   temperature_fahrenheit        124136 non-null  float64
#  9   condition_text                124136 non-null  str
#  10  wind_mph                      124136 non-null  float64
#  11  wind_kph                      124136 non-null  float64
#  12  wind_degree                   124136 non-null  int64
#  13  wind_direction                124136 non-null  str
#  14  pressure_mb                   124136 non-null  float64
#  15  pressure_in                   124136 non-null  float64
#  16  precip_mm                     124136 non-null  float64
#  17  precip_in                     124136 non-null  float64
#  18  humidity                      124136 non-null  int64
#  19  cloud                         124136 non-null  int64
#  20  feels_like_celsius            124136 non-null  float64
#  21  feels_like_fahrenheit         124136 non-null  float64
#  22  visibility_km                 124136 non-null  float64
#  23  visibility_miles              124136 non-null  float64
#  24  uv_index                      124136 non-null  float64
#  25  gust_mph                      124136 non-null  float64
#  26  gust_kph                      124136 non-null  float64
#  27  air_quality_Carbon_Monoxide   124136 non-null  float64
#  28  air_quality_Ozone             124136 non-null  float64
#  29  air_quality_Nitrogen_dioxide  124136 non-null  float64
#  30  air_quality_Sulphur_dioxide   124136 non-null  float64
#  31  air_quality_PM2.5             124136 non-null  float64
#  32  air_quality_PM10              124136 non-null  float64
#  33  air_quality_us-epa-index      124136 non-null  int64
#  34  air_quality_gb-defra-index    124136 non-null  int64
#  35  sunrise                       124136 non-null  str
#  36  sunset                        124136 non-null  str
#  37  moonrise                      124136 non-null  str
#  38  moonset                       124136 non-null  str
#  39  moon_phase                    124136 non-null  str
#  40  moon_illumination             124136 non-null  int64
# dtypes: float64(23), int64(7), str(11)
# memory usage: 38.8 MB
# None
#
# --- First 5 Rows ---
#        country     location_name  latitude  longitude        timezone  \
# 0  Afghanistan             Kabul     34.52      69.18      Asia/Kabul
# 1      Albania            Tirana     41.33      19.82   Europe/Tirane
# 2      Algeria           Algiers     36.76       3.05  Africa/Algiers
# 3      Andorra  Andorra La Vella     42.50       1.52  Europe/Andorra
# 4       Angola            Luanda     -8.84      13.23   Africa/Luanda
#
#    last_updated_epoch      last_updated  temperature_celsius  \
# 0          1715849100  2024-05-16 13:15                 26.6
# 1          1715849100  2024-05-16 10:45                 19.0
# 2          1715849100  2024-05-16 09:45                 23.0
# 3          1715849100  2024-05-16 10:45                  6.3
# 4          1715849100  2024-05-16 09:45                 26.0
#
#    temperature_fahrenheit condition_text  ...  air_quality_PM2.5  \
# 0                    79.8  Partly Cloudy  ...                8.4
# 1                    66.2  Partly cloudy  ...                1.1
# 2                    73.4          Sunny  ...               10.4
# 3                    43.3  Light drizzle  ...                0.7
# 4                    78.8  Partly cloudy  ...              183.4
#
#    air_quality_PM10  air_quality_us-epa-index air_quality_gb-defra-index  \
# 0              26.6                         1                          1
# 1               2.0                         1                          1
# 2              18.4                         1                          1
# 3               0.9                         1                          1
# 4             262.3                         5                         10
#
#     sunrise    sunset  moonrise   moonset      moon_phase  moon_illumination
# 0  04:50 AM  06:50 PM  12:12 PM  01:11 AM  Waxing Gibbous                 55
# 1  05:21 AM  07:54 PM  12:58 PM  02:14 AM  Waxing Gibbous                 55
# 2  05:40 AM  07:50 PM  01:15 PM  02:14 AM  Waxing Gibbous                 55
# 3  06:31 AM  09:11 PM  02:12 PM  03:31 AM  Waxing Gibbous                 55
# 4  06:12 AM  05:55 PM  01:17 PM  12:38 AM  Waxing Gibbous                 55
#
# [5 rows x 41 columns]

# %% [markdown]
# Statistical summary to spot anomalies.

# %%
# Statistical Summary of Numerical Columns
print("--- Statistical Summary ---")
display(df.describe())

# Check for Missing Values
print("\n--- Missing Values Count ---")
print(df.isnull().sum())
# Out:
# --- Statistical Summary ---
#             latitude      longitude  last_updated_epoch  temperature_celsius  \
# count  124136.000000  124136.000000        1.241360e+05        124136.000000
# mean       19.193085      21.992858        1.743471e+09            21.633843
# std        24.426646      65.792707        1.593454e+07             9.566241
# min       -41.300000    -175.200000        1.715849e+09           -29.800000
# 25%         3.750000      -6.836100        1.729676e+09            16.300000
# 50%        17.250000      23.240000        1.743500e+09            24.100000
# 75%        40.400000      50.580000        1.757231e+09            28.100000
# max        64.150000     179.220000        1.771056e+09            49.200000
#
#        temperature_fahrenheit       wind_mph       wind_kph    wind_degree  \
# count           124136.000000  124136.000000  124136.000000  124136.000000
# mean                70.942661       8.070967      12.992551     169.241018
# std                 17.219092       7.379596      11.873256     103.430657
# min                -21.600000       2.200000       3.600000       1.000000
# 25%                 61.300000       4.000000       6.500000      80.000000
# 50%                 75.400000       6.900000      11.200000     162.000000
# 75%                 82.600000      11.000000      17.600000     256.000000
# max                120.600000    1841.200000    2963.200000     360.000000
#
#          pressure_mb    pressure_in  ...       gust_kph  \
# count  124136.000000  124136.000000  ...  124136.000000
# mean     1014.059290      29.944516  ...      18.309223
# std        10.630259       0.313872  ...      14.015566
# min       947.000000      27.960000  ...       3.600000
# 25%      1010.000000      29.830000  ...      10.400000
# 50%      1014.000000      29.930000  ...      15.500000
# 75%      1018.000000      30.060000  ...      24.300000
# max      3006.000000      88.770000  ...    2970.400000
#
#        air_quality_Carbon_Monoxide  air_quality_Ozone  \
# count                124136.000000      124136.000000
# mean                    477.583492          58.989835
# std                     784.126354          31.161792
# min                   -9999.000000           0.000000
# 25%                     212.000000          39.000000
# 50%                     303.400000          56.000000
# 75%                     473.850000          75.000000
# max                   38879.398000         480.700000
#
#        air_quality_Nitrogen_dioxide  air_quality_Sulphur_dioxide  \
# count                 124136.000000                124136.000000
# mean                      15.275060                    10.698594
# std                       24.319822                    37.049426
# min                        0.000000                 -9999.000000
# 25%                        1.650000                     1.050000
# 50%                        5.450000                     2.450000
# 75%                       17.760000                     8.650000
# max                      427.700000                   521.330000
#
#        air_quality_PM2.5  air_quality_PM10  air_quality_us-epa-index  \
# count      124136.000000     124136.000000             124136.000000
# mean           24.622462         49.249932                  1.710841
# std            37.901198        152.015649                  0.950965
# min             0.168000      -1848.150000                  1.000000
# 25%             7.121000         10.050000                  1.000000
# 50%            14.250000         20.350000                  1.000000
# 75%            28.120000         42.200000                  2.000000
# max          1614.100000       6037.290000                  6.000000
#
#        air_quality_gb-defra-index  moon_illumination
# count               124136.000000      124136.000000
# mean                     2.635875          49.838677
# std                      2.473284          34.979745
# min                      1.000000           0.000000
# 25%                      1.000000          15.000000
# 50%                      2.000000          50.000000
# 75%                      3.000000          84.000000
# max                     10.000000         100.000000
#
# [8 rows x 30 columns]
# --- Missing Values Count ---
# country                         0
# location_name                   0
# latitude                        0
# longitude                       0
# timezone                        0
# last_updated_epoch              0
# last_updated                    0
# temperature_celsius             0
# temperature_fahrenheit          0
# condition_text                  0
# wind_mph                        0
# wind_kph                        0
# wind_degree                     0
# wind_direction                  0
# pressure_mb                     0
# pressure_in                     0
# precip_mm                       0
# precip_in                       0
# humidity                        0
# cloud                           0
# feels_like_celsius              0
# feels_like_fahrenheit           0
# visibility_km                   0
# visibility_miles                0
# uv_index                        0
# gust_mph                        0
# gust_kph                        0
# air_quality_Carbon_Monoxide     0
# air_quality_Ozone               0
# air_quality_Nitrogen_dioxide    0
# air_quality_Sulphur_dioxide     0
# air_quality_PM2.5               0
# air_quality_PM10                0
# air_quality_us-epa-index        0
# air_quality_gb-defra-index      0
# sunrise                         0
# sunset                          0
# moonrise                        0
# moonset                         0
# moon_phase                      0
# moon_illumination               0
# dtype: int64

# %% [markdown]
# Data Cleaning: Handling duplicates, nulls, and date conversion.

# %%
# 1. Remove Duplicates
initial_rows = len(df)
df = df.drop_duplicates()
print(f"Removed {initial_rows - len(df)} duplicate rows.")

# 2. Handle Missing Values
# Dropping rows where critical weather data is missing
df_clean = df.dropna(subset=['temperature_celsius', 'condition_text', 'country'])
print(f"Rows after dropping nulls: {len(df_clean)}")

# 3. Date Conversion
# Convert 'last_updated' column to datetime objects
if 'last_updated' in df_clean.columns:
    df_clean['last_updated'] = pd.to_datetime(df_clean['last_updated'])
    print("Converted 'last_updated' to datetime.")
# Out:
# Removed 0 duplicate rows.
# Rows after dropping nulls: 124136
# Converted 'last_updated' to datetime.

# %% [markdown]
# Data Aggregation: Grouping by Month and Country.

# %%
# Create a 'Month' column for aggregation
df_clean['month_period'] = df_clean['last_updated'].dt.to_period('M')

# Aggregate specific columns
monthly_summary = df_clean.groupby(['country', 'month_period'])[[
    'temperature_celsius', 
    'precip_mm', 
    'humidity', 
    'wind_kph'
]].mean().reset_index()

print("Monthly aggregation complete.")
display(monthly_summary.head())
# Out:
# Monthly aggregation complete.
#        country month_period  temperature_celsius  precip_mm   humidity  \
# 0  Afghanistan      2024-05            20.305882   0.108824  38.058824
# 1  Afghanistan      2024-06            25.590000   0.072667  24.833333
# 2  Afghanistan      2024-07            31.303448   0.000345  17.931034
# 3  Afghanistan      2024-08            30.848387   0.037097  20.548387
# 4  Afghanistan      2024-09            28.216667   0.014333  13.733333
#
#     wind_kph
# 0  11.517647
# 1  17.110000
# 2  20.731034
# 3  20.196774
# 4  12.223333

# %% [markdown]
# Save the processed files for the next milestone.

# %%
# Save Cleaned Data
df_clean.to_csv(CLEAN_FILE, index=False)
print(f"Saved cleaned data to: {CLEAN_FILE}")

# Save Aggregated Summary
monthly_summary.to_csv(MONTHLY_FILE, index=False)
print(f"Saved monthly summary to: {MONTHLY_FILE}")
# Out:
# Saved cleaned data to: data\cleaned_weather_data.csv
# Saved monthly summary to: data\monthly_weather_summary.csv
